# %%
import pandas as pd
import numpy as np

# %%
entrenamiento = {'x': [100, 120, 200, 300, 380, 400, 415, 500]
           , 'y': [1.5, 1.3, 2.8, 3.5, 4, 3.9, 4.9, 8]}

prueba = {'x': [220, 410],
          'y': [2, 5.1]}

df_entrenamiento = pd.DataFrame(entrenamiento)
df_prueba = pd.DataFrame(prueba)

sum_y = df_entrenamiento['y'].sum()
sum_x = df_entrenamiento['x'].sum()
sum_xy = (df_entrenamiento['x'] * df_entrenamiento['y']).sum()
sum_x2 = (df_entrenamiento['x'] ** 2).sum()
n = len(df_entrenamiento)


b1 = (n * sum_xy - sum_x * sum_y) / (n * sum_x2 - sum_x ** 2)
b0 = (sum_y - b1 * sum_x) / n

print(f"b0: {b0}, b1: {b1}")
print("sum_x:", sum_x, " sum_y:", sum_y, " sum_xy:", sum_xy, " sum_x2:", sum_x2, " n:", n)

df_prueba['y_pred'] = b0 + b1 * df_prueba['x']
for(i, row) in df_prueba.iterrows():
    print(f"x: {row['x']}, y_real: {row['y']}, y_pred: {row['y_pred']}")
# Out:
# b0: -0.2414482205637456, b1: 0.01318078085486955
# sum_x: 2415  sum_y: 29.9  sum_xy: 11029.5  sum_x2: 881025  n: 8
# x: 220.0, y_real: 2.0, y_pred: 2.6583235675075554
# x: 410.0, y_real: 5.1, y_pred: 5.16267192993277
